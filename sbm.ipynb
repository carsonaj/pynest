# %%
import numpy as np    
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure, text
import networkx as nx

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pynest.rkg as rkg
import pynest.sbm as sbm

# %%
lab_mat = np.zeros((1000, 2))
lab_mat[0:500, 0] = 1
lab_mat[500:1000, 1] = 1

# %%
for p in [.51, .6, .7, .8, .9, .99]:
    ppm = sbm.PPM(p, lab_mat)
    a = rkg.samp_adj_mat(ppm.prob_mat)
    x_hat = rkg.get_adj_spec_emb(a, 2)
    plt.subplots(figsize=(6, 6))
    plt.scatter(x_hat[:, 0], x_hat[:, 1], s=1)
# Out:
# (<Figure size 432x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f7cc4361130>)
# (<Figure size 432x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f7cc42ce580>)
# (<Figure size 432x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f7cc42ffa00>)
# (<Figure size 432x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f7cc42aedc0>)
# (<Figure size 432x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f7cc426e280>)
# (<Figure size 432x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f7cc4223640>)

# %%
p = .6
ppm = sbm.PPM(p, lab_mat)
W = np.array([1, -1] * 500)

Psi = ppm.bloc_prob_mat
bloc_prob_spec = rkg.get_sd(Psi)

lam = bloc_prob_spec[0]
U = bloc_prob_spec[1]
Lam_sqrt = np.diag(lam)**.5

B1 = U @ Lam_sqrt
B1
#Z = lab_mat @ B1 + W
# Out:
# array([[ 0.70710678, -0.31622777],
#        [ 0.70710678,  0.31622777]])

# %%
P = Z @ Z.transpose()
P
A = rkg.samp_adj_mat(P)
X_hat = rkg.get_adj_spec_emb(A, 2)
plt.subplots(figsize=(6, 6))
plt.scatter(x_hat[:, 0], x_hat[:, 1], s=1)
# Out:
# 503.9999999999907
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-4a837e9d25cd> in <module>
#       1 P = Z @ Z.transpose()
#       2 P
# ----> 3 A = rkg.samp_adj_mat(P)
#       4 X_hat = rkg.get_adj_spec_emb(A, 2)
#       5 plt.subplots(figsize=(6, 6))
#
# ~/Desktop/Github/pynest/pynest/rkg.py in samp_adj_mat(p)
#      32 # sample adjacency matrix
#      33 def samp_adj_mat(p):
# ---> 34     n = p.shape[0]
#      35     ind = np.triu_indices(n, k=1)
#      36     a_vals = np.random.binomial(1, p[ind])
#
# IndexError: tuple index out of range

# %%
Z @ Z.transpose()
# Out:
# array([[0.6, 0.6, 0.6, ..., 0.4, 0.4, 0.4],
#        [0.6, 0.6, 0.6, ..., 0.4, 0.4, 0.4],
#        [0.6, 0.6, 0.6, ..., 0.4, 0.4, 0.4],
#        ...,
#        [0.4, 0.4, 0.4, ..., 0.6, 0.6, 0.6],
#        [0.4, 0.4, 0.4, ..., 0.6, 0.6, 0.6],
#        [0.4, 0.4, 0.4, ..., 0.6, 0.6, 0.6]])
